# %% [markdown]
# <a href="https://colab.research.google.com/github/aditya207/NLP_CriminalCaseInfo/blob/master/NLP_pdfinfo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install PyPDF2
# Out:
# ...
#      |████████████████████████████████| 81kB 2.4MB/s
# ...
#   Created wheel for PyPDF2: filename=PyPDF2-1.26.0-cp36-none-any.whl size=61085 sha256=3a4d70de2f3d624502bb81bab70ba5a22f689f9457d68267221fed492e58c54a
#   Stored in directory: /root/.cache/pip/wheels/53/84/19/35bc977c8bf5f0c23a8a011aa958acd4da4bbd7a229315c1b7
# Successfully built PyPDF2
# ...

# %%
import PyPDF2 as pdf
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-ae32ea3e-61ba-4b9c-962d-622f80194332" name="files[]" multiple disabled />
#      <output id="result-ae32ea3e-61ba-4b9c-962d-622f80194332">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving english1.pdf to english1.pdf
# ...

# %%
file = open('english1.pdf','rb')

# %%
file
# Out:
# <_io.BufferedReader name='english1.pdf'>

# %%
pdf_reader = pdf.PdfFileReader(file)

# %%
pdf_reader

# %%
# !pip install textract
# Out:
# ...
#      |████████████████████████████████| 112kB 8.5MB/s
# ...
#      |████████████████████████████████| 112kB 48.2MB/s
# ...
#      |████████████████████████████████| 102kB 9.4MB/s
# ...
#      |████████████████████████████████| 5.6MB 49.6MB/s
# ...
#      |████████████████████████████████| 51kB 5.4MB/s
# ...
#      |████████████████████████████████| 32.8MB 67kB/s
# ...
#      |████████████████████████████████| 8.9MB 36.9MB/s
# ...
#      |████████████████████████████████| 9.7MB 33.5MB/s
# ...
#      |████████████████████████████████| 81kB 8.9MB/s
# ...
#      |████████████████████████████████| 143kB 52.5MB/s
# ...
#   Created wheel for EbookLib: filename=EbookLib-0.17.1-cp36-none-any.whl size=38164 sha256=77841b8f9a09267b8e24c7780a6ebee986263166cb266059a0f1e2a5c5ead6d1
#   Stored in directory: /root/.cache/pip/wheels/84/11/01/951369cbbf8f96878786a1f4da68bd7ac19a5d945b38e03d54
# ...
#   Created wheel for docx2txt: filename=docx2txt-0.8-cp36-none-any.whl size=3965 sha256=efa7eb3b50e90990bc4504a68ef26c3290f45f1b1c56ce854aace8153ae10567
# ...

# %%
# !pip install regex
# Out:
# ...
#      |████████████████████████████████| 645kB 2.8MB/s
# ...

# %%
num_pages = pdf_reader.numPages
count = 0
text = ""

# %%
while count < num_pages:
    pageObj = pdf_reader.getPage(count)
    count +=1
    text += pageObj.extractText()

# %%
if text != "":
   text = text
else:
  text = textract.process(fileurl, method='tesseract',language='eng')

# %%
tokens = word_tokenize(text)

# %%
punctuations = ['(',')',';',':','[',']',',','.']

# %%
stop_words = stopwords.words('english')

# %%
keywords = [word for word in tokens if not word in stop_words and not word in punctuations]

# %%
print(keywords)
# Out:
# ['S.C.C', 'No', '519/2017', 'Exh', 'No', 'IN', 'THE', 'COURT', 'OF', 'MAGISTRATE', 'F.C.', 'COURT', 'NO.2', 'AT', 'NEWASA', 'PARTICULARS', 'UNDER', 'CHAPTER', 'XX', 'OF', 'THE', 'CODE', 'OF', 'CRIMINAL', 'PROCEDURE', '1', 'Date', 'offence', '25/05/2017', '2', 'Date', 'Report', '25/05/2017', '3', 'Name', 'informant', 'N.', 'K.', 'Sangle', 'PC', 'B.No', '1775', 'Traffic', 'Control', 'Branch', 'Ahmednagar', '4', 'Name', 'age', '&', 'address', 'Rahul', 'Navnath', 'Chavan', 'accused', 'R/o', 'Chanda', 'Tal', 'Newasa', '5', 'Particulars', 'offence', 'That', '25/05/2017', '14.30', 'hours', 'public', 'place', 'i.e', 'Ghodegaon', 'Shanishingnapur', 'road', 'Ghodegaon', 'Tal', 'Newasa', 'accused', 'found', 'carrying', '5', 'passengers', 'piaggio', 'rickshaw', 'without', 'permit', 'regard', 'contemplated', 'M.V', 'Act', 'thereby', 'committed', 'offence', 'defined', 'Sec', '66', '1', 'punishable', 'Sec', '192', 'M.V', 'Act', 'within', 'cognizance', 'Secondly', 'date', 'time', 'place', 'accused',
# ...
